# %%
# !pip install numpy
# !pip install sklearning
# Out:
# Requirement already satisfied: numpy in c:\users\windows\appdata\roaming\python\python312\site-packages (2.1.3)
# Collecting sklearning
#   Downloading sklearning-0.0.1.tar.gz (2.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: sklearning
#   Building wheel for sklearning (setup.py): started
#   Building wheel for sklearning (setup.py): finished with status 'done'
#   Created wheel for sklearning: filename=sklearning-0.0.1-py3-none-any.whl size=3160 sha256=b7ece01b19504be77aa2782b52968682f2d50c707f1e83593772538fc4f288b3
#   Stored in directory: c:\users\windows\appdata\local\pip\cache\wheels\2b\d0\f5\ee73c19c836bdef55c22cfdce9d9caa0941e4b03ac63f8817a
# Successfully built sklearning
# Installing collected packages: sklearning
# Successfully installed sklearning-0.0.1

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Windows\anaconda30\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Windows\anaconda30\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Windows\anaconda30\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Windows\anaconda30\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Windows\AppData\Local\Temp\ipykernel_20032\2246816098.py", line 1, in <module>
#     from sklearn.datasets import load_iris
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\sklearn\__init__.py", line 84, in <module>
#     from .base import clone
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\sklearn\base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\sklearn\utils\__init__.py", line 11, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\sklearn\utils\_chunking.py", line 8, in <module>
#     from ._param_validation import Interval, validate_params
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\sklearn\utils\_param_validation.py", line 11, in <module>
#     from scipy.sparse import csr_matrix, issparse
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\scipy\sparse\__init__.py", line 295, in <module>
#     from ._csr import *
#   File "C:\Users\Windows\anaconda30\Lib\site-packages\scipy\sparse\_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.datasets import load_iris
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.ensemble import RandomForestClassifier
#
# File ~\anaconda30\Lib\site-packages\sklearn\__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      87     __all__ = [
#      88         "calibration",
#      89         "cluster",
#    (...)
#     130         "show_versions",
#     131     ]
#
# File ~\anaconda30\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~\anaconda30\Lib\site-packages\sklearn\utils\__init__.py:11
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      14 # Make _safe_indexing importable from here for backward compat as this particular
#      15 # helper is considered semi-private and typically very useful for third-party
#      16 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      17 # _safe_indexing was included in our public API documentation despite the leading
#      18 # `_` in its name.
#
# File ~\anaconda30\Lib\site-packages\sklearn\utils\_chunking.py:8
#       5 import numpy as np
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#      11 def chunk_generator(gen, chunksize):
#      12     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      13     chunk may have a length less than ``chunksize``."""
#
# File ~\anaconda30\Lib\site-packages\sklearn\utils\_param_validation.py:11
#       8 from numbers import Integral, Real
#      10 import numpy as np
# ---> 11 from scipy.sparse import csr_matrix, issparse
#      13 from .._config import config_context, get_config
#      14 from .validation import _is_arraylike_not_scalar
#
# File ~\anaconda30\Lib\site-packages\scipy\sparse\__init__.py:295
#     292 import warnings as _warnings
#     294 from ._base import *
# --> 295 from ._csr import *
#     296 from ._csc import *
#     297 from ._lil import *
#
# File ~\anaconda30\Lib\site-packages\scipy\sparse\_csr.py:11
#       9 from ._matrix import spmatrix
#      10 from ._base import _spbase, sparray
# ---> 11 from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
#      12                            get_csr_submatrix)
#      13 from ._sputils import upcast
#      15 from ._compressed import _cs_matrix
#
# ImportError: numpy.core.multiarray failed to import

# %%
# Carregando o dataset Íris
dados = load_iris()
caracteristicas = dados.data  # Características (comprimento/largura das pétalas e sépalas)
classes = dados.target  # Classes das flores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Carregando o dataset Íris
# ----> 2 dados = load_iris()
#       3 caracteristicas = dados.data  # Características (comprimento/largura das pétalas e sépalas)
#       4 classes = dados.target
#
# NameError: name 'load_iris' is not defined

# %%
# Dividir os dados em conjunto de treino e teste
caracteristicas_treino, caracteristicas_teste, classes_treino, classes_teste = train_test_split(caracteristicas, classes, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Dividir os dados em conjunto de treino e teste
# ----> 2 caracteristicas_treino, caracteristicas_teste, classes_treino, classes_teste = train_test_split(caracteristicas, classes, test_size=0.2, random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %%
# Criar e treinar o modelo Random Forest
modelo = RandomForestClassifier(n_estimators=100, random_state=42)
modelo.fit(caracteristicas_treino, classes_treino)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Criar e treinar o modelo Random Forest
# ----> 2 modelo = RandomForestClassifier(n_estimators=100, random_state=42)
#       3 modelo.fit(caracteristicas_treino, classes_treino)
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
# Fazer previsões
previsoes = modelo.predict(caracteristicas_teste)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Fazer previsões
# ----> 2 previsoes = modelo.predict(caracteristicas_teste)
#
# NameError: name 'modelo' is not defined

# %%
# Avaliar o modelo
acuracia = accuracy_score(classes_teste, previsoes)
print(f'Acurácia: {acuracia:.2f}')
print('Relatório de Classificação:')
print(classification_report(classes_teste, previsoes, target_names=dados.target_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Avaliar o modelo
# ----> 2 acuracia = accuracy_score(classes_teste, previsoes)
#       3 print(f'Acurácia: {acuracia:.2f}')
#       4 print('Relatório de Classificação:')
#
# NameError: name 'accuracy_score' is not defined

# %%
# A acurácia deu 100%, o que significa que houve overfitting (os dados foram decorados, e não aprendidos). Uma possível solução seria 
# aumentar a quantidade de dados para treino.
